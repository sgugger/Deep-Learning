# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.text import *
import html

# %%
BOS = 'xbos'  # beginning-of-sentence tag
FLD = 'xfld'  # data field tag

PATH=Path('../../data/fr-wiki/french')

# %% [markdown]
# # Standarize format

# %%
LANG_FILENAMES = [str(f) for f in PATH.rglob("*/*")]

# %%
len(LANG_FILENAMES), LANG_FILENAMES[:5]
# Out:
# (3906,
#  ['..\\..\\data\\fr-wiki\\french\\AA\\wiki_00',
#   '..\\..\\data\\fr-wiki\\french\\AA\\wiki_01',
#   '..\\..\\data\\fr-wiki\\french\\AA\\wiki_02',
#   '..\\..\\data\\fr-wiki\\french\\AA\\wiki_03',
#   '..\\..\\data\\fr-wiki\\french\\AA\\wiki_04'])

# %%
LANG_TEXT = []
for fn in tqdm(LANG_FILENAMES):
    for line in open(fn, encoding='utf8'):
        LANG_TEXT.append(json.loads(line))
        
LANG_TEXT = pd.DataFrame(LANG_TEXT)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 3906/3906 [01:59<00:00, 32.67it/s]

# %%
LANG_TEXT.head()
# Out:
#    id                                               text  \
# 0   3  Antoine Meillet\n\nPaul Jules Antoine Meillet,...
# 1   7  Algèbre linéaire\n\nL’algèbre linéaire est la ...
# 2   9  Algèbre générale\n\nL'algèbre générale, ou alg...
# 3  10  Algorithmique\n\nLalgorithmique est l'étude et...
# 4  11  Politique en Argentine\n\nL'Argentine est une ...
#
#                     title                                     url
# 0         Antoine Meillet   https://fr.wikipedia.org/wiki?curid=3
# 1        Algèbre linéaire   https://fr.wikipedia.org/wiki?curid=7
# 2        Algèbre générale   https://fr.wikipedia.org/wiki?curid=9
# 3           Algorithmique  https://fr.wikipedia.org/wiki?curid=10
# 4  Politique en Argentine  https://fr.wikipedia.org/wiki?curid=11

# %%
LANG_TEXT.to_csv(PATH/'wiki_fr.csv')

# %%
# Getting rid of the title name in the text field
def split_title_from_text(text):
    words = text.split("\n\n")
    if len(words) >= 2:
        return ''.join(words[1:])
    else:
        return ''.join(words)
    
LANG_TEXT['text'] = LANG_TEXT['text'].apply(lambda x: split_title_from_text(x))

# %%
LANG_TEXT.head()
# Out:
#    id                                               text  \
# 0   3  Paul Jules Antoine Meillet, né le à Moulins (A...
# 1   7  L’algèbre linéaire est la branche des mathémat...
# 2   9  L'algèbre générale, ou algèbre abstraite, est ...
# 3  10  Lalgorithmique est l'étude et la production de...
# 4  11  L'Argentine est une république présidentielle ...
#
#                     title                                     url
# 0         Antoine Meillet   https://fr.wikipedia.org/wiki?curid=3
# 1        Algèbre linéaire   https://fr.wikipedia.org/wiki?curid=7
# 2        Algèbre générale   https://fr.wikipedia.org/wiki?curid=9
# 3           Algorithmique  https://fr.wikipedia.org/wiki?curid=10
# 4  Politique en Argentine  https://fr.wikipedia.org/wiki?curid=11

# %%
LANG_TEXT.to_csv(PATH/'wiki_fr1.csv', header=False, index=False)

# %% [markdown]
# Sorting the articles by length and keeping the first million.

# %%
LANG_TEXT = pd.read_csv(PATH/'wiki_fr1.csv', header=None)

# %%
LANG_TEXT = LANG_TEXT.assign(length = 0)

# %%
LANG_TEXT.columns = ['id', 'text', 'title', 'url', 'length']

# %%
LANG_TEXT = LANG_TEXT.assign(labels = 0).pipe(lambda x: x[['labels', 'text', 'length']])

# %%
LANG_TEXT.head()
# Out:
#    labels                                               text  length
# 0       0  Paul Jules Antoine Meillet, né le à Moulins (A...       0
# 1       0  L’algèbre linéaire est la branche des mathémat...       0
# 2       0  L'algèbre générale, ou algèbre abstraite, est ...       0
# 3       0  Lalgorithmique est l'étude et la production de...       0
# 4       0  L'Argentine est une république présidentielle ...       0

# %%
LANG_TEXT['length'] = LANG_TEXT['text'].str.len()

# %%
LANG_TEXT = LANG_TEXT.sort_values(by=['length'], ascending=False)

# %%
LANG_TEXT.to_csv(PATH/'wiki_fr1.csv', header=False, index=False)

# %%
LANG_TEXT = LANG_TEXT[LANG_TEXT['length'] > 100]

# %%
LANG_TEXT = LANG_TEXT.iloc[0:1000000]

# %% [markdown]
# Splitting 10% for validation.

# %%
trn_texts,val_texts = sklearn.model_selection.train_test_split(LANG_TEXT.pipe(lambda x: x[['labels', 'text']]), test_size=0.1)

# %%
trn_texts.to_csv(PATH/'train.csv', header=False, index=False)
val_texts.to_csv(PATH/'valid.csv', header=False, index=False)

# %% [markdown]
# # Tokenize

# %%
chunksize = 5000

# %%
re1 = re.compile(r'  +')

def fixup(x):
    x = x.replace('#39;', "'").replace('amp;', '&').replace('#146;', "'").replace(
        'nbsp;', ' ').replace('#36;', '$').replace('\\n', "\n").replace('quot;', "'").replace(
        '<br />', "\n").replace('\\"', '"').replace('<unk>','u_n').replace(' @.@ ','.').replace(
        ' @-@ ','-').replace('\\', ' \\ ')
    return re1.sub(' ', html.unescape(x))

# %%
df_trn = pd.read_csv(PATH/'train.csv', header=None, chunksize=chunksize)
df_val = pd.read_csv(PATH/'valid.csv', header=None, chunksize=chunksize)

# %%
def get_texts(df, n_lbls=1):
    labels = df.iloc[:,range(n_lbls)].values.astype(np.int64)
    texts = f'\n{BOS} {FLD} 1 ' + df[n_lbls].astype(str)
    for i in range(n_lbls+1, len(df.columns)): texts += f' {FLD} {i-n_lbls} ' + df[i].astype(str)
    texts = texts.apply(fixup).values.astype(str)
    tok = Tokenizer.proc_all_mp(partition_by_cores(texts), lang='fr')
    return tok, list(labels)

def get_all(df, name, n_lbls=1):
    for i, r in enumerate(df):
        print(i)
        tok_, labels_ = get_texts(r, n_lbls)
        #save the partial tokens instead of regrouping them in one big array.
        np.save(PATH/f'{name}_tok{i}.npy', tok_)
    return tok, labels

# %%
get_all(df_trn,'trn',1)

# %%
get_all(df_val,'val',1)

# %% [markdown]
# # Numericalize

# %% [markdown]
# Get the Counter object from all the splitted files.

# %%
def count_them_all(names):
    cnt = Counter()
    for name in names:
        for file in PATH.glob(f'tmp/{name}_tok*'):
            tok = np.load(file)
            cnt_tok = Counter(word for sent in tok for word in sent)
            cnt += cnt_tok
    return cnt

# %%
cnt = count_them_all(['trn'])

# %%
cnt.most_common()
# Out:
# [(',', 404771),
#  ('de', 403453),
#  ('.', 240390),
#  ('la', 229440),
#  ('le', 174666),
#  ('et', 165450),
#  ('à', 143193),
#  ('en', 131044),
#  ("l'", 120337),
#  ('les', 110875),
#  ('"', 110053),
#  ('des', 105044),
#  ('du', 95649),
#  ('est', 91542),
#  ("d'", 84666),
#  ('un', 75756),
#  ('une', 68106),
#  ('il', 65473),
#  ('\r\r\n', 64888),
#  ('(', 59492),
#  ('dans', 59185),
#  (')', 54383),
#  ('par', 53859),
#  ('au', 51115),
#  ('-', 49281),
#  ('pour', 46147),
#  ('qui', 39651),
#  ('a', 34453),
#  ('sur', 33718),
#  ('que', 33183),
#  ('son', 30532),
#  ('t_up', 30484),
#  ('avec', 29857),
#  ('se', 25568),
#  ('plus', 25213),
#  (':', 24598),
#  ('l’', 22258),
#  ('sont', 22242),
#  ('elle', 19998),
#  ('sa', 19070),
#  ('ce', 18273),
#  ('ou', 18171),
#  ('«', 17461),
#  ('»', 17358),
#  ("s'", 16638),
#  ('aux', 16534),
#  ('été', 15906),
#  ('ses', 15597),
#  ("qu'", 15529),
#  ('comme', 15440),
#  ('1', 15148),
#  ('d’', 14818),
#  ('deux', 14337),
#  ('cette', 14224),
#  ('mais', 13323),
#  ('pas', 13032),
#  ('ne', 12358),
#  ('\n', 12050),
#  ('xbos', 12000),
#  ('xfld', 12000),
#  ('\xa0', 11408),
#  ('après', 10851),
#  ('entre', 10787),
#  ('fait', 10383),
#  ('ont', 10330),
#  ('on', 9098),
#  ("n'", 8996),
#  ('était', 8904),
#  ('leur', 8853),
#  ('ainsi', 8269),
#  ('fut', 8266),
#  ('être', 8189),
#  ('alors', 8174),
#  ('dont', 8125),
#  ('lui', 8063),
#  ('où', 8003),
#  ('même', 7969),
#  ('sous', 7730),
#  ('aussi', 7678),
#  ('également', 7674),
#  ('y', 7551),
#  ('ces', 7482),
#  (';', 7358),
#  ('lors', 7220),
#  ('autres', 7208),
#  ('ils', 7147),
#  ('premier', 6980),
#  ('première', 6862),
#  ("'", 6727),
#  ('france', 6695),
#  ('puis', 6326),
#  ('depuis', 6251),
#  ('nom', 6084),
#  ('ville', 6005),
#  ('ans', 5932),
#  ('%', 5925),
#  ('partie', 5844),
#  ('années', 5825),
#  ('plusieurs', 5676),
#  ('trois', 5659),
#  ('avant', 5395),
#  ('contre', 5386),
#  ('très', 5338),
#  ('guerre', 5192),
#  ('peut', 5154),
#  ('groupe', 5144),
#  ('tout', 5010),
#  ("c'", 4900),
#  ('/', 4721),
#  ('fin', 4698),
#  ("jusqu'", 4697),
#  ('vers', 4651),
#  ('fois', 4633),
#  ('commune', 4579),
#  ('avait', 4510),
#  ('français', 4449),
#  ('bien', 4400),
#  ('pays', 4333),
#  ('sans', 4297),
#  ('année', 4292),
#  ('avoir', 4290),
#  ('notamment', 4290),
#  ('place', 4216),
#  ('paris', 4156),
#  ('monde', 3974),
#  ('temps', 3900),
#  ('grand', 3896),
#  ('mort', 3861),
#  ('autre', 3828),
#  ('suite', 3823),
#  ('saison', 3804),
#  ('état', 3780),
#  ('pendant', 3735),
#  ('né', 3734),
#  ('2', 3728),
#  ('leurs', 3688),
#  ('nord', 3676),
#  ('nouveau', 3670),
#  ('encore', 3669),
#  ('tous', 3649),
#  ('l', 3605),
#  ('nouvelle', 3576),
#  ('selon', 3568),
#  ('équipe', 3535),
#  ('cours', 3499),
#  ('général', 3499),
#  ('partir', 3484),
#  ('peu', 3484),
#  ('soit', 3459),
#  ('sud', 3447),
#  ('faire', 3431),
#  ('si', 3414),
#  ('devient', 3402),
#  ('grande', 3371),
#  ('région', 3282),
#  ('donc', 3261),
#  ('club', 3230),
#  ('titre', 3218),
#  ('politique', 3210),
#  ('début', 3183),
#  ('états', 3180),
#  ('parti', 3162),
#  ('tour', 3161),
#  ('quelques', 3145),
#  ('vie', 3122),
#  ('moins', 3086),
#  ('histoire', 3079),
#  ('quatre', 3051),
#  ('famille', 3043),
#  ('s’', 3038),
#  ('lieu', 2995),
#  ('3', 2990),
#  ('durant', 2965),
#  ('nombre', 2945),
#  ('française', 2914),
#  ('ensuite', 2872),
#  ('église', 2843),
#  ('série', 2825),
#  ('the', 2819),
#  ('non', 2796),
#  ('forme', 2787),
#  ('société', 2757),
#  ('dès', 2738),
#  ('étant', 2702),
#  ('cependant', 2690),
#  ('époque', 2686),
#  ('centre', 2686),
#  ('4', 2643),
#  ('qu’', 2598),
#  ('chaque', 2585),
#  ('dernier', 2581),
#  ('nombreux', 2574),
#  ('étaient', 2573),
#  ('origine', 2567),
#  ('part', 2561),
#  ('armée', 2559),
#  ('président', 2537),
#  ('face', 2532),
#  ('ligne', 2525),
#  ('tard', 2512),
#  ('septembre', 2503),
#  ('école', 2487),
#  ('ayant', 2482),
#  ('université', 2480),
#  ('trouve', 2468),
#  ('fils', 2468),
#  ('afin', 2450),
#  ('roi', 2439),
#  ('chez', 2431),
#  ('population', 2428),
#  ('gouvernement', 2423),
#  ('juin', 2411),
#  ('près', 2405),
#  ('prix', 2394),
#  ('mars', 2391),
#  ('album', 2390),
#  ('mois', 2383),
#  ('film', 2380),
#  ('deuxième', 2376),
#  ('unis', 2347),
#  ('certains', 2331),
#  ('celle', 2310),
#  ('souvent', 2310),
#  ('mai', 2308),
#  ('ensemble', 2304),
#  ('permet', 2279),
#  ('ancien', 2273),
#  ('elles', 2271),
#  ('nationale', 2270),
#  ('cet', 2268),
#  ('celui', 2260),
#  ('située', 2249),
#  ('janvier', 2242),
#  ('reste', 2224),
#  ('effet', 2222),
#  ('décembre', 2219),
#  ('tant', 2214),
#  ('octobre', 2199),
#  ('juillet', 2195),
#  ('père', 2192),
#  ('homme', 2189),
#  ('cas', 2189),
#  ('pierre', 2187),
#  ('environ', 2186),
#  ('seconde', 2186),
#  ('5', 2183),
#  ('département', 2183),
#  ('toujours', 2165),
#  ('national', 2161),
#  ('service', 2147),
#  ('période', 2145),
#  ('doit', 2141),
#  ('exemple', 2134),
#  ('europe', 2133),
#  ('2010', 2130),
#  ('conseil', 2117),
#  ('carrière', 2110),
#  ('car', 2104),
#  ('point', 2077),
#  ('novembre', 2068),
#  ('toute', 2064),
#  ('2012', 2063),
#  ('village', 2063),
#  ('10', 2060),
#  ('compte', 2046),
#  ('toutes', 2046),
#  ('jean', 2034),
#  ('niveau', 2031),
#  ('prend', 2025),
#  ('août', 2018),
#  ('eau', 2016),
#  ('château', 2015),
#  ('système', 2013),
#  ('peuvent', 2012),
#  ('cinq', 2009),
#  ('avril', 2009),
#  ('île', 2002),
#  ('sein', 2000),
#  ('membres', 1997),
#  ('ouest', 1996),
#  ('jour', 1985),
#  ('sera', 1970),
#  ('membre', 1950),
#  ('of', 1949),
#  ('2008', 1942),
#  ('nommé', 1939),
#  ('furent', 1929),
#  ('2009', 1926),
#  ('2007', 1917),
#  ('rôle', 1914),
#  ('parmi', 1912),
#  ('nombreuses', 1911),
#  ('territoire', 1909),
#  ('6', 1898),
#  ('troisième', 1887),
#  ('âge', 1875),
#  ('études', 1872),
#  ('2011', 1871),
#  ('droit', 1860),
#  ('maison', 1860),
#  ('tête', 1858),
#  ('février', 1857),
#  ('championnat', 1852),
#  ('projet', 1850),
#  ('travail', 1843),
#  ('2014', 1843),
#  ('match', 1834),
#  ('2013', 1831),
#  ('ordre', 1819),
#  ('communes', 1817),
#  ('jours', 1807),
#  ('situé', 1805),
#  ('jeu', 1797),
#  ('habitants', 1768),
#  ('mondiale', 1764),
#  ('développement', 1761),
#  ('2015', 1760),
#  ('pouvoir', 1752),
#  ('premiers', 1749),
#  ('coupe', 1740),
#  ('œuvre', 1736),
#  ('grâce', 1733),
#  ('succès', 1732),
#  ('site', 1730),
#  ('points', 1715),
#  ('long', 1712),
#  ('personnes', 1710),
#  ('chef', 1696),
#  ('jeune', 1690),
#  ('ailleurs', 1679),
#  ('musique', 1678),
#  ('base', 1678),
#  ('devant', 1665),
#  ('loi', 1662),
#  ('art', 1655),
#  ('enfants', 1648),
#  ('ministre', 1644),
#  ('poste', 1642),
#  ('création', 1641),
#  ('union', 1635),
#  ('petit', 1622),
#  ('rue', 1620),
#  ('mise', 1619),
#  ('corps', 1616),
#  ('2006', 1609),
#  ('dernière', 1608),
#  ('mouvement', 1607),
#  ('construction', 1600),
#  ('hommes', 1600),
#  ('laquelle', 1597),
#  ('république', 1593),
#  ('s', 1593),
#  ('cela', 1587),
#  ('terre', 1582),
#  ('finale', 1579),
#  ('déjà', 1574),
#  ('élections', 1573),
#  ('saint', 1570),
#  ('beaucoup', 1565),
#  ('public', 1562),
#  ('remporte', 1557),
#  ('but', 1557),
#  ('8', 1551),
#  ('six', 1546),
#  ('seul', 1545),
#  ("aujourd'hui", 1543),
#  ('louis', 1531),
#  ('plan', 1530),
#  ('anglais', 1530),
#  ('production', 1529),
#  ('présente', 1527),
#  ('côté', 1521),
#  ('dit', 1519),
#  ('direction', 1518),
#  ('division', 1515),
#  ('20', 1508),
#  ('n’', 1503),
#  ('terme', 1494),
#  ('connu', 1493),
#  ('raison', 1489),
#  ('15', 1480),
#  ('2016', 1479),
#  ('lorsque', 1478),
#  ('agit', 1478),
#  ('royaume', 1477),
#  ('quand', 1473),
#  ('porte', 1471),
#  ('new', 1469),
#  ('tandis', 1457),
#  ('charles', 1454),
#  ('communauté', 1453),
#  ('musée', 1452),
#  ('travaux', 1449),
#  ('...', 1446),
#  ('second', 1435),
#  ('ancienne', 1434),
#  ('jeux', 1433),
#  ('association', 1432),
#  ('compagnie', 1432),
#  ('militaire', 1431),
#  ('formation', 1427),
#  ('participe', 1424),
#  ('12', 1424),
#  ('route', 1420),
#  ('ligue', 1418),
#  ('passe', 1418),
#  ('va', 1418),
#  ('fille', 1417),
#  ('version', 1413),
#  ('joue', 1411),
#  ('abord', 1407),
#  ('7', 1401),
#  ('femme', 1395),
#  ('type', 1394),
#  ('zone', 1392),
#  ('différents', 1391),
#  ('retour', 1388),
#  ('john', 1388),
#  ('victoire', 1386),
#  ('autour', 1386),
#  ('écrit', 1385),
#  ('international', 1381),
#  ('siège', 1380),
#  ('finalement', 1379),
#  ('an', 1379),
#  ('2005', 1377),
#  ('rivière', 1376),
#  ('ceux', 1375),
#  ('particulier', 1374),
#  ('ii', 1369),
#  ('liste', 1368),
#  ('commence', 1368),
#  ('milieu', 1367),
#  ('bataille', 1367),
#  ('obtient', 1366),
#  ('parfois', 1364),
#  ('donne', 1361),
#  ('or', 1360),
#  ('aurait', 1360),
#  ('certaines', 1358),
#  ('2000', 1358),
#  ('joueur', 1357),
#  ('allemagne', 1344),
#  ('premières', 1343),
#  ('seulement', 1341),
#  ('organisation', 1335),
#  ('surtout', 1334),
#  ('livre', 1327),
#  ('malgré', 1327),
#  ('cause', 1324),
#  ('américain', 1324),
#  ('font', 1313),
#  ('existe', 1305),
#  ('utilisé', 1298),
#  ('mis', 1296),
#  ('produit', 1290),
#  ('scène', 1289),
#  ('réseau', 1286),
#  ('eu', 1285),
#  ('grands', 1272),
#  ('2004', 1271),
#  ('date', 1271),
#  ('langue', 1269),
#  ('millions', 1269),
#  ('cadre', 1267),
#  ('avaient', 1261),
#  ('italie', 1261),
#  ('rapport', 1258),
#  ('créé', 1256),
#  ('œuvres', 1256),
#  ('recherche', 1253),
#  ('seule', 1248),
#  ('petite', 1245),
#  ('nous', 1241),
#  ('fonction', 1237),
#  ('manière', 1235),
#  ('différentes', 1231),
#  ('parc', 1229),
#  ('gauche', 1228),
#  ('important', 1226),
#  ('directeur', 1224),
#  ('30', 1223),
#  ('françois', 1219),
#  ('domaine', 1219),
#  ('bois', 1216),
#  ('18', 1215),
#  ('femmes', 1212),
#  ('marque', 1210),
#  ('mer', 1210),
#  ('plupart', 1210),
#  ('gare', 1207),
#  ('auteur', 1202),
#  ('grandes', 1198),
#  ('9', 1198),
#  ('chanson', 1192),
#  ('suivante', 1191),
#  ('théâtre', 1191),
#  ('jamais', 1189),
#  ('culture', 1188),
#  ('province', 1188),
#  ('nouvelles', 1188),
#  ('celui-ci', 1185),
#  ('11', 1184),
#  ('eux', 1183),
#  ('aide', 1181),
#  ('lequel', 1179),
#  ('voir', 1179),
#  ('rencontre', 1172),
#  ('rapidement', 1169),
#  ('2002', 1167),
#  ('moment', 1164),
#  ('16', 1163),
#  ('principalement', 1162),
#  ('1990', 1162),
#  ('14', 1157),
#  ('appelé', 1154),
#  ('haut', 1152),
#  ('toutefois', 1151),
#  ('2017', 1147),
#  ('activité', 1146),
#  ('édition', 1146),
#  ('britannique', 1143),
#  ('voit', 1142),
#  ('york', 1142),
#  ('…', 1133),
#  ('frère', 1131),
#  ('enfin', 1130),
#  ('moyenne', 1129),
#  ('élu', 1129),
#  ('là', 1128),
#  ('suivant', 1127),
#  ('25', 1127),
#  ('marie', 1126),
#  ('style', 1125),
#  ('travers', 1122),
#  ('généralement', 1119),
#  ('taux', 1116),
#  ('jeunes', 1112),
#  ('mère', 1112),
#  ('présence', 1108),
#  ('demande', 1105),
#  ('football', 1102),
#  ('fer', 1102),
#  ('17', 1100),
#  ('paul', 1100),
#  ('rejoint', 1099),
#  ('groupes', 1099),
#  ('troupes', 1095),
#  ('cour', 1090),
#  ('possède', 1090),
#  ('tels', 1089),
#  ('espagne', 1088),
#  ('administration', 1085),
#  ('révolution', 1084),
#  ('services', 1084),
#  ('allemand', 1082),
#  ('propre', 1081),
#  ('moyen', 1081),
#  ('entreprise', 1077),
#  ('communiste', 1076),
#  ('angleterre', 1075),
#  ('meilleur', 1074),
#  ('activités', 1074),
#  ('action', 1071),
#  ('lac', 1068),
#  ('quartier', 1065),
#  ('reçoit', 1064),
#  ('prendre', 1060),
#  ('voie', 1058),
#  ('roman', 1057),
#  ('position', 1055),
#  ('principal', 1053),
#  ('occasion', 1052),
#  ('affaires', 1050),
#  ('13', 1048),
#  ('1980', 1047),
#  ('intérieur', 1046),
#  ('canton', 1042),
#  ('née', 1041),
#  ('épouse', 1041),
#  ('droite', 1039),
#  ('populaire', 1036),
#  ('retrouve', 1034),
#  ('politiques', 1033),
#  ('situation', 1031),
#  ('2003', 1027),
#  ('classement', 1027),
#  ('importante', 1025),
#  ('–', 1025),
#  ('empire', 1024),
#  ('droits', 1021),
#  ('1999', 1020),
#  ('professeur', 1019),
#  (']', 1019),
#  ('24', 1018),
#  ('mesure', 1017),
#  ('internationale', 1017),
#  ('fort', 1017),
#  ('publié', 1015),
#  ('étude', 1015),
#  ('[', 1013),
#  ('équipes', 1011),
#  ('rouge', 1011),
#  ('possible', 1011),
#  ('sept', 1009),
#  ('objet', 1008),
#  ('vue', 1007),
#  ('2001', 1007),
#  ('particulièrement', 1004),
#  ('journal', 1004),
#  ('met', 1002),
#  ('créée', 1000),
#  ('—', 999),
#  ('construit', 999),
#  ('henri', 996),
#  ('espace', 990),
#  ('0', 990),
#  ('outre', 987),
#  ('afrique', 986),
#  ('éléments', 986),
#  ('produits', 986),
#  ('matchs', 985),
#  ('aucun', 983),
#  ('décide', 983),
#  ('sens', 982),
#  ('russie', 982),
#  ('contrôle', 981),
#  ('villes', 981),
#  ('classe', 980),
#  ('américaine', 978),
#  ('forces', 977),
#  ('campagne', 977),
#  ('robert', 974),
#  ('1970', 972),
#  ('donné', 970),
#  ('force', 969),
#  ('jacques', 969),
#  ('termine', 969),
#  ('proche', 966),
#  ('fit', 965),
#  ('voix', 962),
#  ('composé', 962),
#  ('ni', 961),
#  ('historique', 958),
#  ('serait', 956),
#  ('suisse', 953),
#  ('lui-même', 949),
#  ('trop', 943),
#  ('départ', 942),
#  ('assez', 941),
#  ('comité', 939),
#  ('programme', 937),
#  ('entrée', 936),
#  ('buts', 935),
#  ('nouveaux', 935),
#  ('dix', 935),
#  ('al', 935),
#  ('émission', 934),
#  ('économique', 934),
#  ('façon', 933),
#  ('c’', 932),
#  ('arrivée', 932),
#  ('réalisé', 931),
#  ('espèces', 931),
#  ('atteint', 925),
#  ('auprès', 925),
#  ('celle-ci', 923),
#  ('air', 923),
#  ('mission', 917),
#  ('1998', 917),
#  ('22', 917),
#  ('semble', 916),
#  ('capitale', 913),
#  ('chambre', 911),
#  ('annonce', 910),
#  ('faisant', 908),
#  ('1960', 905),
#  ('d', 903),
#  ('personnage', 901),
#  ('21', 899),
#  ('19', 899),
#  ('japon', 894),
#  ('générale', 893),
#  ('course', 892),
#  ('attaque', 891),
#  ('vallée', 889),
#  ('londres', 888),
#  ('!', 886),
#  ('anciens', 886),
#  ('combat', 886),
#  ('derniers', 882),
#  ('signe', 879),
#  ('celles', 879),
#  ('bâtiment', 879),
#  ('23', 878),
#  ('modèle', 878),
#  ('festival', 877),
#  ('prince', 877),
#  ('défense', 875),
#  ('sciences', 874),
#  ('sort', 872),
#  ('comte', 870),
#  ('rome', 869),
#  ('désormais', 867),
#  ('mettre', 863),
#  ('commission', 863),
#  ('and', 862),
#  ('régime', 859),
#  ('sortie', 855),
#  ('pris', 854),
#  ('article', 851),
#  ('heures', 849),
#  ('mètres', 847),
#  ('résultats', 844),
#  ('genre', 843),
#  ('sorti', 842),
#  ('traité', 841),
#  ('télévision', 840),
#  ('devenu', 839),
#  ('cité', 839),
#  ('qualité', 835),
#  ('honneur', 833),
#  ('chemin', 833),
#  ('accès', 832),
#  ('canada', 830),
#  ('devenir', 828),
#  ('artistes', 827),
#  ('enseignement', 827),
#  ('salle', 825),
#  ('assemblée', 825),
#  ('films', 824),
#  ('meurt', 824),
#  ('champion', 824),
#  ('majorité', 821),
#  ('argent', 821),
#  ('russe', 820),
#  ('académie', 820),
#  ('québec', 818),
#  ('espèce', 818),
#  ('santé', 817),
#  ('valeur', 817),
#  ('quatrième', 816),
#  ('comprend', 816),
#  ('influence', 816),
#  ('total', 815),
#  ('m', 814),
#  ('centrale', 814),
#  ('libre', 813),
#  ('marché', 812),
#  ('cinéma', 812),
#  ('28', 810),
#  ('technique', 810),
#  ('lignes', 810),
#  ('terrain', 809),
#  ('large', 805),
#  ('joseph', 804),
#  ('belgique', 804),
#  ('aucune', 803),
#  ('?', 802),
#  ('plutôt', 800),
#  ('compétition', 799),
#  ('conditions', 796),
#  ('publique', 795),
#  ('néanmoins', 794),
#  ('unique', 793),
#  ('européenne', 792),
#  ('chine', 792),
#  ('utilisation', 792),
#  ('éducation', 791),
#  ('26', 790),
#  ('passage', 789),
#  ('principaux', 789),
#  ('quant', 789),
#  ('faut', 788),
#  ('contrat', 788),
#  ('secrétaire', 787),
#  ('i', 784),
#  ('économie', 780),
#  ('personne', 780),
#  ('clubs', 780),
#  ('sécurité', 779),
#  ('exposition', 779),
#  ('élection', 777),
#  ("lorsqu'", 776),
#  ('données', 773),
#  ('san', 772),
#  ('quitte', 771),
#  ('moitié', 771),
#  ('issue', 771),
#  ('huit', 770),
#  ('certain', 769),
#  ('représente', 769),
#  ('pratique', 769),
#  ('publie', 768),
#  ('vient', 768),
#  ('double', 766),
#  ('forte', 766),
#  ('divers', 766),
#  ('permettant', 766),
#  ('pièces', 765),
#  ('charge', 765),
#  ('célèbre', 764),
#  ('terres', 764),
#  ('arts', 763),
#  ('haute', 763),
#  ('nuit', 761),
#  ('radio', 761),
#  ('1997', 761),
#  ('maire', 760),
#  ('surface', 760),
#  ('inscrit', 759),
#  ('côte', 758),
#  ('apparaît', 757),
#  ('phase', 757),
#  ('vitesse', 757),
#  ('source', 756),
#  ('critique', 756),
#  ('commerce', 755),
#  ('savoie', 755),
#  ('presque', 754),
#  ('nature', 752),
#  ('prise', 751),
#  ('ouvrage', 748),
#  ('amérique', 747),
#  ('stade', 746),
#  ('michel', 746),
#  ('iii', 746),
#  ('enfant', 744),
#  ('référence', 744),
#  ('collection', 744),
#  ('1996', 743),
#  ('régions', 743),
#  ('fonctions', 740),
#  ('structure', 739),
#  ('soutien', 738),
#  ('principale', 737),
#  ('titres', 734),
#  ('je', 734),
#  ('énergie', 734),
#  ('pont', 734),
#  ('jusqu’', 732),
#  ('rend', 732),
#  ('secteur', 731),
#  ('taille', 729),
#  ('unité', 728),
#  ('réalise', 727),
#  ('longue', 727),
#  ('kilomètres', 726),
#  ('station', 724),
#  ('joueurs', 723),
#  ('palais', 722),
#  ('maître', 721),
#  ('mariage', 720),
#  ('parties', 719),
#  ('c', 719),
#  ('autant', 719),
#  ('allemands', 719),
#  ('allemande', 718),
#  ('eut', 717),
#  ('évêque', 716),
#  ('information', 716),
#  ('in', 716),
#  ('gestion', 715),
#  ('etc.', 715),
#  ('1995', 714),
#  ('actuellement', 713),
#  ('simple', 713),
#  ('théorie', 713),
#  ('naissance', 713),
#  ('fondation', 712),
#  ('doivent', 712),
#  ('accord', 712),
#  ('mode', 711),
#  ('représentant', 710),
#  ('patrimoine', 710),
#  ('image', 710),
#  ('passé', 710),
#  ('relations', 710),
#  ('reprises', 710),
#  ('presse', 710),
#  ('militaires', 709),
#  ('propose', 709),
#  ('îles', 709),
#  ('james', 709),
#  ('épisode', 709),
#  ('italien', 706),
#  ('devint', 705),
#  ('travaille', 704),
#  ('27', 702),
#  ('chaîne', 701),
#  ('connue', 701),
#  ('hiver', 701),
#  ('coup', 701),
#  ('mot', 701),
#  ('forêt', 701),
#  ('considéré', 699),
#  ('dispose', 699),
#  ('constitue', 699),
#  ('peuple', 699),
#  ('ait', 698),
#  ('proximité', 698),
#  ('soviétique', 698),
#  ('lettres', 697),
#  ('1994', 697),
#  ('peintre', 697),
#  ('diverses', 696),
#  ('continue', 695),
#  ('armes', 693),
#  ('bon', 693),
#  ('chapelle', 692),
#  ('obtenir', 692),
#  ('duc', 690),
#  ('évolution', 688),
#  ('ministère', 687),
#  ('protection', 687),
#  ('pu', 687),
#  ('reçu', 687),
#  ('1992', 686),
#  ('david', 686),
#  ('choix', 686),
#  ('tableau', 685),
#  ('&', 685),
#  ('minutes', 684),
#  ('derrière', 683),
#  ("c'est-à-dire", 683),
#  ('juifs', 683),
#  ('soldats', 683),
#  ('°', 683),
#  ('revue', 682),
#  ('blanc', 681),
#  ('utilisée', 681),
#  ('tournoi', 680),
#  ('sociale', 680),
#  ('directement', 679),
#  ('port', 679),
#  ('pied', 678),
#  ('institut', 678),
#  ('idée', 678),
#  ('cœur', 678),
#  ('<', 676),
#  ('1993', 675),
#  ('police', 674),
#  ('constitution', 674),
#  ('faible', 673),
#  ('chargé', 672),
#  ('philippe', 672),
#  ('royal', 672),
#  ('capitaine', 672),
#  ('arrive', 671),
#  ('actuel', 671),
#  ('empereur', 669),
#  ('personnages', 668),
#  ('tours', 668),
#  ('offre', 668),
#  ('côtés', 667),
#  ('sujet', 666),
#  ('1991', 665),
#  ('pourrait', 665),
#  ('processus', 665),
#  ('livres', 664),
#  ('altitude', 664),
#  ('dieu', 664),
#  ('supérieur', 661),
#  ('front', 661),
#  ('usage', 660),
#  ('transport', 659),
#  ('opposition', 658),
#  ('objets', 658),
#  ('hôtel', 657),
#  ('environnement', 656),
#  ('question', 656),
#  ('probablement', 655),
#  ('opération', 655),
#  ('longueur', 654),
#  ('statut', 653),
#  ('via', 653),
#  ('garde', 653),
#  ('50', 652),
#  ('noir', 652),
#  ('tournée', 651),
#  ('parlement', 649),
#  ('industrie', 649),
#  ('actuelle', 648),
#  ('créer', 648),
#  ('historiques', 647),
#  ('zones', 647),
#  ('seront', 647),
#  ('sélection', 647),
#  ('fondé', 646),
#  ('comté', 646),
#  ('dernières', 646),
#  ('montre', 646),
#  ('intérêt', 644),
#  ('petits', 644),
#  ('reprend', 642),
#  ('débuts', 641),
#  ('vit', 641),
#  ('fondée', 640),
#  ('sol', 640),
#  ('vu', 640),
#  ...]

# %%
max_vocab = 60000
min_freq = 5

# %%
itos = [o for o,c in cnt.most_common(max_vocab) if c > min_freq]
itos.insert(0,'_pad_')
itos.insert(0,'_unk_')

# %%
len(itos)
# Out:
# 48446

# %%
stoi = collections.defaultdict(int,{s:i for (i,s) in enumerate(itos)})

# %% [markdown]
# Numericalize each partial file.

# %%
def numericalize(name):
    results = []
    for file in tqdm(PATH.glob(f'tmp/{name}_tok*')):
        tok = np.load(file)
        results.append(np.array([[stoi[word] for word in sent] for sent in tok]))
    return np.concatenate(results)

# %%
trn_ids = numericalize('trn')
np.save(PATH/'tmp/trn_ids.npy', trn_ids)

# %%
val_ids = numericalize('val')
np.save(PATH/'tmp/trn_ids.npy', val_ids)
